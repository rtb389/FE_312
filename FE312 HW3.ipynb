# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_stata('bitbootcamp/BetaSortedPortfolios.dta')

# %%
df.head(10)
# Out:
#      month  dec1  dec2  dec3  dec4  dec5  dec6  dec7  dec8  dec9  dec10  \
# 0  1963m07  1.35  0.77  0.08 -0.28 -0.59 -1.20 -0.45 -1.44 -1.88  -0.80
# 1  1963m08  3.52  3.89  4.29  5.26  5.19  7.55  7.48  4.99  9.12  10.39
# 2  1963m09 -3.09 -2.24 -0.54 -0.98 -1.33 -0.27 -0.63 -0.99 -1.90  -3.71
# 3  1963m10  1.25 -0.12  2.00  5.13  2.34  1.78  6.57  4.84  3.08   3.04
# 4  1963m11 -0.91 -0.15  1.60 -2.03 -1.00 -0.69 -1.30 -0.53 -0.21   0.51
# 5  1963m12  3.86  0.63  2.31  1.84  2.95  2.36  1.27  3.39  0.37   1.26
# 6  1964m01  3.74  1.41  2.74  2.79  1.71  2.95  2.96  4.27  2.08   0.96
# 7  1964m02  1.08  1.72  0.62  2.09  2.48  1.66  1.70  3.83  2.53   3.82
# 8  1964m03  1.05  0.76  0.05  1.12  3.07  1.69  2.38  3.78  5.99   6.06
# 9  1964m04  2.65  1.81  1.57  1.39 -0.85  0.07 -2.24 -2.70 -1.73  -4.93
#
#    mktrf    rf   mkt
# 0  -0.39  0.27 -0.12
# 1   5.07  0.25  5.32
# 2  -1.57  0.27 -1.30
# 3   2.53  0.29  2.82
# 4  -0.85  0.27 -0.58
# 5   1.83  0.29  2.12
# ...

# %%
df.describe()
# Out:
#              dec1        dec2        dec3        dec4        dec5        dec6  \
# count  640.000000  640.000000  640.000000  640.000000  640.000000  640.000000
# mean     0.931672    0.887812    0.953828    1.032282    0.913406    0.996515
# std      3.459633    3.803136    4.052993    4.580554    4.737556    5.054574
# min    -13.050000  -15.120000  -20.320000  -23.990000  -24.360001  -24.770000
# 25%     -0.895000   -1.162500   -1.310000   -1.585000   -1.912500   -1.852500
# 50%      1.135000    0.945000    0.965000    1.085000    1.155000    1.230000
# 75%      3.005000    3.040000    3.515000    3.972500    3.750000    3.972500
# max     18.660000   18.709999   15.460000   18.790001   18.240000   20.080000
#
#              dec7        dec8        dec9       dec10       mktrf          rf  \
# count  640.000000  640.000000  640.000000  640.000000  640.000000  640.000000
# mean     0.883344    1.021812    0.994297    0.982860    0.501406    0.393515
# ...

# %%
df.corr()
# Out:
#            dec1      dec2      dec3      dec4      dec5      dec6      dec7  \
# dec1   1.000000  0.863548  0.797197  0.743227  0.733293  0.714148  0.690902
# dec2   0.863548  1.000000  0.899375  0.833527  0.830682  0.811542  0.772332
# dec3   0.797197  0.899375  1.000000  0.881899  0.889676  0.865185  0.851908
# dec4   0.743227  0.833527  0.881899  1.000000  0.905450  0.904247  0.891897
# dec5   0.733293  0.830682  0.889676  0.905450  1.000000  0.927399  0.926907
# dec6   0.714148  0.811542  0.865185  0.904247  0.927399  1.000000  0.931714
# dec7   0.690902  0.772332  0.851908  0.891897  0.926907  0.931714  1.000000
# dec8   0.648672  0.735696  0.819652  0.869005  0.899906  0.913946  0.925356
# dec9   0.610570  0.694586  0.782041  0.839010  0.882053  0.895903  0.914376
# dec10  0.572514  0.652839  0.745035  0.806914  0.843861  0.871384  0.894063
# mktrf  0.782622  0.851711  0.906195  0.936347  0.945369  0.945688  0.943275
# ...

# %%
df2 = df.corr()

# %%
del df2['rf']
del df2['mktrf']

# %%
df2 = df2.drop('mktrf')
df2 = df2.drop('rf')

# %%
df2.to_csv('bitbootcamp/temp.csv')

# %%
df3 = df.describe().transpose()

# %%
df3 = df3[['mean','std']]

# %%
df3.to_csv('bitbootcamp/temp2.csv')

# %% [markdown]
# ##

# %%
df2
# Out:
#            dec1      dec2      dec3      dec4      dec5      dec6      dec7  \
# dec1   1.000000  0.863548  0.797197  0.743227  0.733293  0.714148  0.690902
# dec2   0.863548  1.000000  0.899375  0.833527  0.830682  0.811542  0.772332
# dec3   0.797197  0.899375  1.000000  0.881899  0.889676  0.865185  0.851908
# dec4   0.743227  0.833527  0.881899  1.000000  0.905450  0.904247  0.891897
# dec5   0.733293  0.830682  0.889676  0.905450  1.000000  0.927399  0.926907
# dec6   0.714148  0.811542  0.865185  0.904247  0.927399  1.000000  0.931714
# dec7   0.690902  0.772332  0.851908  0.891897  0.926907  0.931714  1.000000
# dec8   0.648672  0.735696  0.819652  0.869005  0.899906  0.913946  0.925356
# dec9   0.610570  0.694586  0.782041  0.839010  0.882053  0.895903  0.914376
# dec10  0.572514  0.652839  0.745035  0.806914  0.843861  0.871384  0.894063
# mkt    0.787308  0.855850  0.908226  0.937925  0.947184  0.946904  0.943825
#
#            dec8      dec9     dec10       mkt
# ...

# %%
df3
# Out:
#            mean       std
# dec1   0.931672  3.459633
# dec2   0.887812  3.803136
# dec3   0.953828  4.052993
# dec4   1.032282  4.580554
# dec5   0.913406  4.737556
# dec6   0.996515  5.054574
# dec7   0.883344  5.410477
# dec8   1.021812  5.995303
# dec9   0.994297  6.642066
# dec10  0.982860  7.879422
# mktrf  0.501406  4.427111
# rf     0.393515  0.263740
# mkt    0.894922  4.414528

# %%
#df.to_csv('temp3.csv')

# %%
df4 = pd.read_csv('temp3.csv')

# %%
df4
# Out:
#      Unnamed: 0    month  1-Dec  2-Dec  3-Dec  4-Dec  5-Dec  6-Dec  7-Dec  \
# 0             0  1963m07   1.35   0.77   0.08  -0.28  -0.59  -1.20  -0.45
# 1             1  1963m08   3.52   3.89   4.29   5.26   5.19   7.55   7.48
# 2             2  1963m09  -3.09  -2.24  -0.54  -0.98  -1.33  -0.27  -0.63
# 3             3  1963m10   1.25  -0.12   2.00   5.13   2.34   1.78   6.57
# 4             4  1963m11  -0.91  -0.15   1.60  -2.03  -1.00  -0.69  -1.30
# 5             5  1963m12   3.86   0.63   2.31   1.84   2.95   2.36   1.27
# 6             6  1964m01   3.74   1.41   2.74   2.79   1.71   2.95   2.96
# 7             7  1964m02   1.08   1.72   0.62   2.09   2.48   1.66   1.70
# 8             8  1964m03   1.05   0.76   0.05   1.12   3.07   1.69   2.38
# 9             9  1964m04   2.65   1.81   1.57   1.39  -0.85   0.07  -2.24
# 10           10  1964m05   1.64   1.71   0.23   2.76   2.21   0.84   0.67
# 11           11  1964m06   1.52   2.20   3.81   0.34   1.13   1.39   2.01
# ...

# %%
del df4['Unnamed: 0']

# %%
from pandas.stats.api import ols

# %%
res1 = ols(y=df4['p-rf'], x=df4['1-Dec']-df4['rf'])
print res1
# Out:
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <x> + <intercept>
#
# Number of Observations:         640
# Number of Degrees of Freedom:   2
#
# R-squared:         0.9874
# Adj R-squared:     0.9874
#
# Rmse:              0.3818
#
# F-stat (1, 638): 50054.4361, p-value:     0.0000
#
# Degrees of Freedom: model 1, resid 638
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
#              x     0.9769     0.0044     223.73     0.0000     0.9683     0.9854
#      intercept     0.0070     0.0153       0.46     0.6461    -0.0229     0.0370
# ---------------------------------End of Summary---------------------------------

# %%
res2 = ols(y=df4['p-rf'], x=df4['2-Dec']-df4['rf'])
print res2
# Out:
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <x> + <intercept>
#
# Number of Observations:         640
# Number of Degrees of Freedom:   2
#
# R-squared:         0.7066
# Adj R-squared:     0.7062
#
# Rmse:              1.8432
#
# F-stat (1, 638):  1536.7544, p-value:     0.0000
#
# Degrees of Freedom: model 1, resid 638
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
#              x     0.7513     0.0192      39.20     0.0000     0.7137     0.7888
#      intercept     0.1614     0.0735       2.20     0.0284     0.0174     0.3054
# ---------------------------------End of Summary---------------------------------

# %%
res3 = ols(y=df4['p-rf'], x=df4['3-Dec']-df4['rf'])
print res3
# Out:
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <x> + <intercept>
#
# Number of Observations:         640
# Number of Degrees of Freedom:   2
#
# R-squared:         0.5762
# Adj R-squared:     0.5755
#
# Rmse:              2.2155
#
# F-stat (1, 638):   867.2861, p-value:     0.0000
#
# Degrees of Freedom: model 1, resid 638
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
#              x     0.6351     0.0216      29.45     0.0000     0.5928     0.6774
#      intercept     0.1769     0.0884       2.00     0.0458     0.0036     0.3501
# ---------------------------------End of Summary---------------------------------

# %%
res4 = ols(y=df4['p-rf'], x=df4['4-Dec']-df4['rf'])
print res4
# Out:
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <x> + <intercept>
#
# Number of Observations:         640
# Number of Degrees of Freedom:   2
#
# R-squared:         0.4817
# Adj R-squared:     0.4809
#
# Rmse:              2.4500
#
# F-stat (1, 638):   592.8830, p-value:     0.0000
#
# Degrees of Freedom: model 1, resid 638
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
#              x     0.5138     0.0211      24.35     0.0000     0.4725     0.5552
#      intercept     0.2045     0.0978       2.09     0.0369     0.0129     0.3962
# ---------------------------------End of Summary---------------------------------

# %%
res5 = ols(y=df4['p-rf'], x=df4['5-Dec']-df4['rf'])
print res5
# Out:
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <x> + <intercept>
#
# Number of Observations:         640
# Number of Degrees of Freedom:   2
#
# R-squared:         0.4592
# Adj R-squared:     0.4584
#
# Rmse:              2.5025
#
# F-stat (1, 638):   541.7848, p-value:     0.0000
#
# Degrees of Freedom: model 1, resid 638
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
#              x     0.4852     0.0208      23.28     0.0000     0.4444     0.5261
#      intercept     0.2805     0.0995       2.82     0.0050     0.0854     0.4755
# ---------------------------------End of Summary---------------------------------

# %%
res6 = ols(y=df4['p-rf'], x=df4['6-Dec']-df4['rf'])
print res6
# Out:
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <x> + <intercept>
#
# Number of Observations:         640
# Number of Degrees of Freedom:   2
#
# R-squared:         0.4268
# Adj R-squared:     0.4259
#
# Rmse:              2.5763
#
# F-stat (1, 638):   475.1331, p-value:     0.0000
#
# Degrees of Freedom: model 1, resid 638
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
#              x     0.4384     0.0201      21.80     0.0000     0.3989     0.4778
#      intercept     0.2684     0.1026       2.62     0.0091     0.0674     0.4694
# ---------------------------------End of Summary---------------------------------

# %%
res7 = ols(y=df4['p-rf'], x=df4['7-Dec']-df4['rf'])
print res7
# Out:
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <x> + <intercept>
#
# Number of Observations:         640
# Number of Degrees of Freedom:   2
#
# R-squared:         0.3912
# Adj R-squared:     0.3903
#
# Rmse:              2.6551
#
# F-stat (1, 638):   410.0246, p-value:     0.0000
#
# Degrees of Freedom: model 1, resid 638
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
#              x     0.3920     0.0194      20.25     0.0000     0.3540     0.4299
#      intercept     0.3407     0.1054       3.23     0.0013     0.1342     0.5473
# ---------------------------------End of Summary---------------------------------

# %%
res8 = ols(y=df4['p-rf'], x=df4['8-Dec']-df4['rf'])
print res8
# Out:
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <x> + <intercept>
#
# Number of Observations:         640
# Number of Degrees of Freedom:   2
#
# R-squared:         0.3291
# Adj R-squared:     0.3281
#
# Rmse:              2.7873
#
# F-stat (1, 638):   312.9994, p-value:     0.0000
#
# Degrees of Freedom: model 1, resid 638
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
#              x     0.3246     0.0183      17.69     0.0000     0.2887     0.3606
#      intercept     0.3288     0.1108       2.97     0.0031     0.1116     0.5459
# ---------------------------------End of Summary---------------------------------

# %%
res9 = ols(y=df4['p-rf'], x=df4['9-Dec']-df4['rf'])
print res9
# Out:
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <x> + <intercept>
#
# Number of Observations:         640
# Number of Degrees of Freedom:   2
#
# R-squared:         0.2803
# Adj R-squared:     0.2792
#
# Rmse:              2.8869
#
# F-stat (1, 638):   248.5317, p-value:     0.0000
#
# Degrees of Freedom: model 1, resid 638
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
#              x     0.2705     0.0172      15.76     0.0000     0.2369     0.3042
#      intercept     0.3702     0.1146       3.23     0.0013     0.1456     0.5948
# ---------------------------------End of Summary---------------------------------

# %%
res10 = ols(y=df4['p-rf'], x=df4['10-Dec']-df4['rf'])
print res10
# Out:
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <x> + <intercept>
#
# Number of Observations:         640
# Number of Degrees of Freedom:   2
#
# R-squared:         0.2318
# Adj R-squared:     0.2306
#
# Rmse:              2.9827
#
# F-stat (1, 638):   192.4729, p-value:     0.0000
#
# Degrees of Freedom: model 1, resid 638
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
#              x     0.2073     0.0149      13.87     0.0000     0.1781     0.2366
#      intercept     0.4105     0.1182       3.47     0.0006     0.1788     0.6423
# ---------------------------------End of Summary---------------------------------

# %%
res11 = ols(y=df4['p-rf'], x=df4['mkt']-df4['rf'])
print res11
# Out:
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <x> + <intercept>
#
# Number of Observations:         640
# Number of Degrees of Freedom:   2
#
# R-squared:         0.5288
# Adj R-squared:     0.5280
#
# Rmse:              2.3361
#
# F-stat (1, 638):   715.8736, p-value:     0.0000
#
# Degrees of Freedom: model 1, resid 638
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
#              x     0.5585     0.0209      26.76     0.0000     0.5176     0.5994
#      intercept     0.2527     0.0929       2.72     0.0067     0.0705     0.4348
# ---------------------------------End of Summary---------------------------------
